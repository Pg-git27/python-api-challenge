# %% [markdown]
# # WeatherPy

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
import json
import scipy.stats as st
from scipy.stats import linregress
# Import API key
from api_keys import g_key
from citipy import citipy
# https://pypi.org/project/citipy/ (pip install citipy)
# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %% [markdown]
# ## Generate Cities List

# %%
# List for holding latitudes-longitudes and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
latitudes = np.random.uniform(low=-90.000, high=90.000, size=1500)
longitudes = np.random.uniform(low=-180.000, high=180.000, size=1500)
latitudes_longitudes = zip(latitudes, longitudes)

# Identify nearest city for each latitudes-longitudes combination
for everylat_lng in latitudes_longitudes:
    city = citipy.nearest_city(everylat_lng[0], everylat_lng[1]).city_name
    
    # If the city is not already present, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 620

# %%
city_name = []
cloudiness = []
country = []
date = []
humidity = []
latitude_list = []
longitude_list = []
maximum_temp = []
wind_speed = []
index_counter = 0
set_counter = 1

# %% [markdown]
# ### Perform API Calls

# %%
from api_keys import weather_api_key

# Save config information.
url = "http://api.openweathermap.org/data/2.5/weather?"
units = "imperial"

# Build partial query URL
query_url = f"{url}appid={weather_api_key}&units={units}&q="

# %%
# For each city name in cities list, do below things...used exception handling
for index, city in enumerate(cities, start = 1):
    try:
        response = requests.get(query_url + city).json()
        city_name.append(response["name"])
        cloudiness.append(response["clouds"]["all"])
        country.append(response["sys"]["country"])
        date.append(response["dt"])
        humidity.append(response["main"]["humidity"])
        latitude_list.append(response["coord"]["lat"])
        longitude_list.append(response["coord"]["lon"])
        maximum_temp.append(response['main']['temp_max'])
        wind_speed.append(response["wind"]["speed"])
        if index_counter > 49:
            index_counter = 0
            set_counter = set_counter + 1
    
        else:
            index_counter = index_counter + 1
            
        print(f"Processing Record {index_counter} of Set {set_counter} : {city}") 
  
    except(KeyError, IndexError):
        print("City not found. Skipping...")
# Out:
# Processing Record 1 of Set 1 : kamaishi
# Processing Record 2 of Set 1 : chokurdakh
# Processing Record 3 of Set 1 : pevek
# Processing Record 4 of Set 1 : atuona
# Processing Record 5 of Set 1 : rio grande
# Processing Record 6 of Set 1 : sakata
# Processing Record 7 of Set 1 : busselton
# Processing Record 8 of Set 1 : rikitea
# Processing Record 9 of Set 1 : taktaszada
# Processing Record 10 of Set 1 : jamestown
# Processing Record 11 of Set 1 : new norfolk
# Processing Record 12 of Set 1 : severo-kurilsk
# Processing Record 13 of Set 1 : kieta
# Processing Record 14 of Set 1 : hilo
# Processing Record 15 of Set 1 : leningradskiy
# Processing Record 16 of Set 1 : tongliao
# Processing Record 17 of Set 1 : ushuaia
# Processing Record 18 of Set 1 : ilulissat
# Processing Record 19 of Set 1 : horta
# Processing Record 20 of Set 1 : bathsheba
# Processing Record 21 of Set 1 : dawlatabad
# Processing Record 22 of Set 1 : hay river
# Processing Record 23 of Set 1 : westport
# Processing Record 24 of Set 1 : manokwari
# City not found. Skipping...
# Processing Record 25 of Set 1 : bandar-e lengeh
# Processing Record 26 of Set 1 : torbay
# Processing Record 27 of Set 1 : barrow
# Processing Record 28 of Set 1 : bredasdorp
# Processing Record 29 of Set 1 : vaini
# Processing Record 30 of Set 1 : ancud
# Processing Record 31 of Set 1 : tilichiki
# Processing Record 32 of Set 1 : kungurtug
# Processing Record 33 of Set 1 : port arthur
# Processing Record 34 of Set 1 : victoria
# Processing Record 35 of Set 1 : manzhouli
# Processing Record 36 of Set 1 : suntar
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 37 of Set 1 : cayenne
# Processing Record 38 of Set 1 : saint-philippe
# Processing Record 39 of Set 1 : jalu
# Processing Record 40 of Set 1 : paracatu
# Processing Record 41 of Set 1 : lorengau
# Processing Record 42 of Set 1 : magadan
# Processing Record 43 of Set 1 : mataura
# City not found. Skipping...
# Processing Record 44 of Set 1 : albany
# Processing Record 45 of Set 1 : souillac
# Processing Record 46 of Set 1 : hobart
# Processing Record 47 of Set 1 : puerto ayora
# City not found. Skipping...
# Processing Record 48 of Set 1 : iqaluit
# Processing Record 49 of Set 1 : qaqortoq
# Processing Record 50 of Set 1 : hithadhoo
# Processing Record 0 of Set 2 : ponta delgada
# Processing Record 1 of Set 2 : alta floresta
# Processing Record 2 of Set 2 : atambua
# Processing Record 3 of Set 2 : asau
# Processing Record 4 of Set 2 : mackay
# Processing Record 5 of Set 2 : bethel
# Processing Record 6 of Set 2 : hereford
# Processing Record 7 of Set 2 : castro
# Processing Record 8 of Set 2 : dingle
# Processing Record 9 of Set 2 : thompson
# Processing Record 10 of Set 2 : port elizabeth
# Processing Record 11 of Set 2 : yellowknife
# Processing Record 12 of Set 2 : kapaa
# Processing Record 13 of Set 2 : lypova dolyna
# Processing Record 14 of Set 2 : kahului
# Processing Record 15 of Set 2 : pokaran
# Processing Record 16 of Set 2 : bluff
# Processing Record 17 of Set 2 : anloga
# Processing Record 18 of Set 2 : ciudad real
# Processing Record 19 of Set 2 : punta arenas
# Processing Record 20 of Set 2 : bengkulu
# Processing Record 21 of Set 2 : cape town
# Processing Record 22 of Set 2 : hermanus
# Processing Record 23 of Set 2 : kavieng
# Processing Record 24 of Set 2 : port alfred
# Processing Record 25 of Set 2 : buala
# Processing Record 26 of Set 2 : taman
# Processing Record 27 of Set 2 : faanui
# Processing Record 28 of Set 2 : bambous virieux
# Processing Record 29 of Set 2 : karla
# Processing Record 30 of Set 2 : fairbanks
# Processing Record 31 of Set 2 : necochea
# Processing Record 32 of Set 2 : shenzhen
# Processing Record 33 of Set 2 : baruun-urt
# Processing Record 34 of Set 2 : qaanaaq
# Processing Record 35 of Set 2 : alyangula
# Processing Record 36 of Set 2 : tarakan
# Processing Record 37 of Set 2 : zalari
# City not found. Skipping...
# Processing Record 38 of Set 2 : avarua
# Processing Record 39 of Set 2 : tasiilaq
# Processing Record 40 of Set 2 : georgetown
# Processing Record 41 of Set 2 : vsetaty
# Processing Record 42 of Set 2 : nemuro
# Processing Record 43 of Set 2 : mar del plata
# Processing Record 44 of Set 2 : lethem
# Processing Record 45 of Set 2 : hudson bay
# Processing Record 46 of Set 2 : nuevo progreso
# City not found. Skipping...
# Processing Record 47 of Set 2 : moose factory
# Processing Record 48 of Set 2 : bonthe
# Processing Record 49 of Set 2 : bagdarin
# Processing Record 50 of Set 2 : klaksvik
# Processing Record 0 of Set 3 : lawton
# Processing Record 1 of Set 3 : upernavik
# Processing Record 2 of Set 3 : karlstad
# Processing Record 3 of Set 3 : ponta do sol
# City not found. Skipping...
# Processing Record 4 of Set 3 : lavrentiya
# Processing Record 5 of Set 3 : kaitangata
# Processing Record 6 of Set 3 : avera
# Processing Record 7 of Set 3 : kodiak
# Processing Record 8 of Set 3 : tiksi
# Processing Record 9 of Set 3 : lagoa
# Processing Record 10 of Set 3 : the valley
# Processing Record 11 of Set 3 : belmonte
# Processing Record 12 of Set 3 : saskylakh
# City not found. Skipping...
# Processing Record 13 of Set 3 : kruisfontein
# Processing Record 14 of Set 3 : codrington
# Processing Record 15 of Set 3 : hampton
# Processing Record 16 of Set 3 : new glasgow
# Processing Record 17 of Set 3 : cabo san lucas
# Processing Record 18 of Set 3 : sobolevo
# Processing Record 19 of Set 3 : butaritari
# Processing Record 20 of Set 3 : arraial do cabo
# Processing Record 21 of Set 3 : iberia
# Processing Record 22 of Set 3 : katsuura
# Processing Record 23 of Set 3 : portland
# Processing Record 24 of Set 3 : takoradi
# Processing Record 25 of Set 3 : woodward
# Processing Record 26 of Set 3 : viedma
# Processing Record 27 of Set 3 : zeerust
# Processing Record 28 of Set 3 : vestmannaeyjar
# City not found. Skipping...
# Processing Record 29 of Set 3 : saldanha
# Processing Record 30 of Set 3 : ahuimanu
# Processing Record 31 of Set 3 : arecibo
# Processing Record 32 of Set 3 : fortuna
# Processing Record 33 of Set 3 : gravelbourg
# Processing Record 34 of Set 3 : batemans bay
# Processing Record 35 of Set 3 : tautira
# Processing Record 36 of Set 3 : ailigandi
# Processing Record 37 of Set 3 : bara
# Processing Record 38 of Set 3 : gamba
# Processing Record 39 of Set 3 : praia da vitoria
# Processing Record 40 of Set 3 : trairi
# Processing Record 41 of Set 3 : mahebourg
# Processing Record 42 of Set 3 : hasaki
# Processing Record 43 of Set 3 : east london
# Processing Record 44 of Set 3 : talnakh
# Processing Record 45 of Set 3 : rawson
# Processing Record 46 of Set 3 : sao joao da barra
# Processing Record 47 of Set 3 : kimbe
# Processing Record 48 of Set 3 : barcelos
# Processing Record 49 of Set 3 : taunggyi
# Processing Record 50 of Set 3 : guamuchil
# Processing Record 0 of Set 4 : chuy
# Processing Record 1 of Set 4 : north bend
# Processing Record 2 of Set 4 : lazaro cardenas
# Processing Record 3 of Set 4 : berlevag
# Processing Record 4 of Set 4 : padang
# Processing Record 5 of Set 4 : ginda
# Processing Record 6 of Set 4 : havelock
# Processing Record 7 of Set 4 : bundaberg
# Processing Record 8 of Set 4 : tuatapere
# Processing Record 9 of Set 4 : vila velha
# Processing Record 10 of Set 4 : udimskiy
# Processing Record 11 of Set 4 : bafoulabe
# Processing Record 12 of Set 4 : palomares
# Processing Record 13 of Set 4 : burnie
# Processing Record 14 of Set 4 : muisne
# Processing Record 15 of Set 4 : lekoni
# Processing Record 16 of Set 4 : khatanga
# Processing Record 17 of Set 4 : lasa
# Processing Record 18 of Set 4 : marquette
# Processing Record 19 of Set 4 : tabatinga
# Processing Record 20 of Set 4 : minot
# Processing Record 21 of Set 4 : port lincoln
# Processing Record 22 of Set 4 : kulynychi
# Processing Record 23 of Set 4 : saint-francois
# Processing Record 24 of Set 4 : vardo
# Processing Record 25 of Set 4 : namibe
# Processing Record 26 of Set 4 : aykhal
# Processing Record 27 of Set 4 : isangel
# Processing Record 28 of Set 4 : narsaq
# Processing Record 29 of Set 4 : carnarvon
# Processing Record 30 of Set 4 : norman wells
# City not found. Skipping...
# Processing Record 31 of Set 4 : mattru
# Processing Record 32 of Set 4 : kenai
# Processing Record 33 of Set 4 : lompoc
# Processing Record 34 of Set 4 : ahipara
# Processing Record 35 of Set 4 : semnan
# Processing Record 36 of Set 4 : kalmar
# Processing Record 37 of Set 4 : kavaratti
# Processing Record 38 of Set 4 : ossora
# Processing Record 39 of Set 4 : tuktoyaktuk
# Processing Record 40 of Set 4 : nisia floresta
# Processing Record 41 of Set 4 : guerrero negro
# Processing Record 42 of Set 4 : jieshi
# Processing Record 43 of Set 4 : geraldton
# Processing Record 44 of Set 4 : aloleng
# Processing Record 45 of Set 4 : makakilo city
# Processing Record 46 of Set 4 : kedrovyy
# Processing Record 47 of Set 4 : iquique
# City not found. Skipping...
# Processing Record 48 of Set 4 : dillon
# Processing Record 49 of Set 4 : mahon
# Processing Record 50 of Set 4 : tezu
# Processing Record 0 of Set 5 : vanimo
# Processing Record 1 of Set 5 : katangli
# Processing Record 2 of Set 5 : toamasina
# Processing Record 3 of Set 5 : ormara
# Processing Record 4 of Set 5 : okhotsk
# Processing Record 5 of Set 5 : pangani
# Processing Record 6 of Set 5 : nanning
# Processing Record 7 of Set 5 : acurenam
# Processing Record 8 of Set 5 : mackenzie
# Processing Record 9 of Set 5 : gisborne
# Processing Record 10 of Set 5 : lawrence
# Processing Record 11 of Set 5 : san cristobal
# Processing Record 12 of Set 5 : nyagan
# Processing Record 13 of Set 5 : san rafael
# Processing Record 14 of Set 5 : salalah
# Processing Record 15 of Set 5 : umm lajj
# Processing Record 16 of Set 5 : nevel
# City not found. Skipping...
# Processing Record 17 of Set 5 : krumbach
# Processing Record 18 of Set 5 : mounana
# Processing Record 19 of Set 5 : lebu
# Processing Record 20 of Set 5 : san policarpo
# Processing Record 21 of Set 5 : pisco
# Processing Record 22 of Set 5 : sydney
# Processing Record 23 of Set 5 : bubaque
# Processing Record 24 of Set 5 : kudahuvadhoo
# Processing Record 25 of Set 5 : fare
# Processing Record 26 of Set 5 : coquimbo
# Processing Record 27 of Set 5 : sao filipe
# Processing Record 28 of Set 5 : chapais
# Processing Record 29 of Set 5 : russell
# City not found. Skipping...
# Processing Record 30 of Set 5 : axim
# Processing Record 31 of Set 5 : auki
# Processing Record 32 of Set 5 : melbu
# Processing Record 33 of Set 5 : south lake tahoe
# Processing Record 34 of Set 5 : brookhaven
# Processing Record 35 of Set 5 : airai
# Processing Record 36 of Set 5 : kamiiso
# Processing Record 37 of Set 5 : yar-sale
# Processing Record 38 of Set 5 : stockerau
# Processing Record 39 of Set 5 : wanning
# Processing Record 40 of Set 5 : thunder bay
# City not found. Skipping...
# Processing Record 41 of Set 5 : nikolskoye
# Processing Record 42 of Set 5 : garden city
# Processing Record 43 of Set 5 : vila franca do campo
# Processing Record 44 of Set 5 : belaya gora
# Processing Record 45 of Set 5 : bowen
# Processing Record 46 of Set 5 : shubarshi
# Processing Record 47 of Set 5 : ribeira grande
# Processing Record 48 of Set 5 : paamiut
# Processing Record 49 of Set 5 : batticaloa
# Processing Record 50 of Set 5 : clyde river
# Processing Record 0 of Set 6 : elban
# Processing Record 1 of Set 6 : dikson
# Processing Record 2 of Set 6 : sancti spiritus
# Processing Record 3 of Set 6 : ust-barguzin
# Processing Record 4 of Set 6 : san patricio
# Processing Record 5 of Set 6 : muzambinho
# Processing Record 6 of Set 6 : yinchuan
# City not found. Skipping...
# Processing Record 7 of Set 6 : kysyl-syr
# Processing Record 8 of Set 6 : olafsvik
# Processing Record 9 of Set 6 : sept-iles
# Processing Record 10 of Set 6 : atbasar
# Processing Record 11 of Set 6 : conde
# Processing Record 12 of Set 6 : road town
# Processing Record 13 of Set 6 : nioro
# Processing Record 14 of Set 6 : bandarbeyla
# Processing Record 15 of Set 6 : high level
# Processing Record 16 of Set 6 : dunedin
# Processing Record 17 of Set 6 : linhares
# Processing Record 18 of Set 6 : kuching
# Processing Record 19 of Set 6 : sabanagrande
# Processing Record 20 of Set 6 : saint albans
# Processing Record 21 of Set 6 : bagru
# Processing Record 22 of Set 6 : bairiki
# Processing Record 23 of Set 6 : benguela
# Processing Record 24 of Set 6 : kemin
# Processing Record 25 of Set 6 : durango
# City not found. Skipping...
# Processing Record 26 of Set 6 : pacific grove
# Processing Record 27 of Set 6 : deputatskiy
# Processing Record 28 of Set 6 : saint george
# City not found. Skipping...
# Processing Record 29 of Set 6 : sorland
# Processing Record 30 of Set 6 : launceston
# Processing Record 31 of Set 6 : kichera
# Processing Record 32 of Set 6 : moerai
# Processing Record 33 of Set 6 : verkhnyaya inta
# Processing Record 34 of Set 6 : quatre cocos
# Processing Record 35 of Set 6 : shimoda
# Processing Record 36 of Set 6 : halifax
# Processing Record 37 of Set 6 : montanha
# Processing Record 38 of Set 6 : khandyga
# Processing Record 39 of Set 6 : mount gambier
# Processing Record 40 of Set 6 : kamen-na-obi
# Processing Record 41 of Set 6 : fernley
# Processing Record 42 of Set 6 : chifeng
# Processing Record 43 of Set 6 : luxor
# Processing Record 44 of Set 6 : mount isa
# Processing Record 45 of Set 6 : tigil
# Processing Record 46 of Set 6 : bentiu
# Processing Record 47 of Set 6 : severomuysk
# Processing Record 48 of Set 6 : yaan
# Processing Record 49 of Set 6 : ulladulla
# Processing Record 50 of Set 6 : srednekolymsk
# Processing Record 0 of Set 7 : batagay-alyta
# Processing Record 1 of Set 7 : ituiutaba
# Processing Record 2 of Set 7 : margate
# Processing Record 3 of Set 7 : matara
# Processing Record 4 of Set 7 : velke mezirici
# Processing Record 5 of Set 7 : laguna
# Processing Record 6 of Set 7 : waterloo
# Processing Record 7 of Set 7 : sarankhola
# Processing Record 8 of Set 7 : half moon bay
# Processing Record 9 of Set 7 : malakwal
# Processing Record 10 of Set 7 : bintulu
# Processing Record 6 of Set 11 : comodoro rivadavia
# Processing Record 7 of Set 11 : wanaka
# Processing Record 8 of Set 11 : cortes
# Processing Record 9 of Set 11 : nalut
# Processing Record 10 of Set 11 : trinidad
# Processing Record 11 of Set 11 : caohai
# Processing Record 12 of Set 11 : lata
# Processing Record 13 of Set 11 : xiongzhou
# Processing Record 14 of Set 11 : maniitsoq
# Processing Record 15 of Set 11 : swift current
# City not found. Skipping...
# Processing Record 16 of Set 11 : nyurba
# Processing Record 17 of Set 11 : muros
# City not found. Skipping...
# Processing Record 18 of Set 11 : beaverlodge
# Processing Record 19 of Set 11 : anori
# Processing Record 20 of Set 11 : san borja
# Processing Record 21 of Set 11 : caravelas
# Processing Record 22 of Set 11 : madera
# Processing Record 23 of Set 11 : beringovskiy
# Processing Record 24 of Set 11 : terekli-mekteb
# Processing Record 25 of Set 11 : ewa beach
# Processing Record 26 of Set 11 : ngunguru
# Processing Record 27 of Set 11 : odweyne
# Processing Record 28 of Set 11 : shelburne
# Processing Record 29 of Set 11 : macae
# Processing Record 30 of Set 11 : yugo-kamskiy
# Processing Record 31 of Set 11 : port-gentil
# Processing Record 32 of Set 11 : neuquen
# City not found. Skipping...
# Processing Record 33 of Set 11 : birstonas
# Processing Record 34 of Set 11 : jevargi
# Processing Record 35 of Set 11 : colares
# Processing Record 36 of Set 11 : cherskiy
# Processing Record 37 of Set 11 : gat
# Processing Record 38 of Set 11 : taoudenni
# Processing Record 39 of Set 11 : barranco
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 40 of Set 11 : boende
# City not found. Skipping...
# Processing Record 41 of Set 11 : lokosovo
# Processing Record 42 of Set 11 : madaoua
# Processing Record 43 of Set 11 : longyearbyen
# Processing Record 44 of Set 11 : bisho
# Processing Record 45 of Set 11 : port blair
# Processing Record 46 of Set 11 : sompeta
# Processing Record 47 of Set 11 : taos
# Processing Record 48 of Set 11 : kasama
# Processing Record 49 of Set 11 : haimen
# Processing Record 50 of Set 11 : colac
# Processing Record 0 of Set 12 : san jose
# Processing Record 1 of Set 12 : akoupe
# Processing Record 2 of Set 12 : broken hill
# Processing Record 3 of Set 12 : balikpapan
# Processing Record 4 of Set 12 : kikwit
# Processing Record 5 of Set 12 : eseka
# Processing Record 6 of Set 12 : los llanos de aridane
# City not found. Skipping...
# Processing Record 7 of Set 12 : samarai
# Processing Record 8 of Set 12 : oriximina
# Processing Record 9 of Set 12 : laibin
# Processing Record 10 of Set 12 : mbala
# Processing Record 11 of Set 12 : manama
# Processing Record 12 of Set 12 : bosaso
# Processing Record 13 of Set 12 : ferrol
# Processing Record 14 of Set 12 : kawalu
# Processing Record 15 of Set 12 : namatanai

# %% [markdown]
# ### Convert Raw Data to DataFrame
# * Export the city data into a .csv.
# * Display the DataFrame

# %%
    weather_dictionary = {
    "City": city_name,
    "Cloudiness": cloudiness,
    "Country": country,
    "Date": date,
    "Humidity": humidity,
    "Lat": latitude_list,
    "Lng": longitude_list,
    "Max Temp": maximum_temp,
    "Wind Speed": wind_speed
}

# %%
weather_dataframe = pd.DataFrame(weather_dictionary)
weather_dataframe.head(10)
weather_dataframe.to_csv("weather_df.csv", index=False)

# %% [markdown]
# ## Plotting the Data
# * Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# * Save the plotted figures as .pngs.

# %% [markdown]
# ## Latitude vs. Temperature Plot

# %%
plt.scatter(weather_dictionary["Lat"], weather_dictionary["Max Temp"], facecolor = "lightblue", edgecolor = "black")
plt.title("City Latitude vs. Max Temperature (01/17/20)")
plt.xlabel("Latitude")
plt.ylabel("Maximum Temperature (F)")
plt.grid(linestyle='-', linewidth=1, alpha = 0.5)
# Save the plotted figure as .pngs
plt.savefig("Latitude vs Max Temperature.png")

# %% [markdown]
# ##Observation- Latitude vs Max Temperature.png:
# #As the latitude increases, temperature drops and the maximum temp. is found around 0 latitude.

# %% [markdown]
# ## Latitude vs. Humidity Plot

# %%
plt.scatter(weather_dataframe["Lat"], weather_dataframe["Humidity"], marker='o', s=30, edgecolors= "black")
plt.title("City Latitude vs Humidity")
plt.ylabel("Humidity Level (%)")
plt.xlabel("Latitude")
plt.grid()
plt.savefig("Latitude vs Humidity.png")

# %% [markdown]
# ##Observation- Latitude vs Humidity:
# #As the latitude gets higher,humidity gets higher too.

# %% [markdown]
# ## Latitude vs. Cloudiness Plot

# %%
plt.scatter(weather_dataframe["Lat"], weather_dataframe["Cloudiness"], marker='o', s=30, edgecolors= "black")
plt.title("City Latitude vs Cloudiness")
plt.ylabel("Cloudiness Level (%)")
plt.xlabel("Latitude")
plt.grid()
# plt.show()
plt.savefig("Latitude vs Cloudiness.png")

# %% [markdown]
# ##Observation- Latitude vs Cloudiness: Cloudiness is all over the latitude.

# %% [markdown]
# ## Latitude vs. Wind Speed Plot

# %%
plt.scatter(weather_dataframe["Lat"], weather_dataframe["Wind Speed"], marker='o', s=30, edgecolors= "black")
plt.title("City Latitude vs Wind Speed")
plt.ylabel("Wind Speed (mph)")
plt.xlabel("Latitude")
plt.grid()
plt.savefig("Latitude vs Wind Speed.png")

# %% [markdown]
# ##Observation- Latitude vs Wind Speed:Wind Speed is present across the latitude

# %% [markdown]
# ## Linear Regression

# %%
# Create Northern and Southern Hemisphere DataFrames
northern_hemisphere = weather_dataframe.loc[weather_dataframe["Lat"] >= 0]
southern_hemisphere = weather_dataframe.loc[weather_dataframe["Lat"] < 0]

# %% [markdown]
# ####  Northern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
#Create a Scatter Plot for Lattitude vs Temperature of City
x_values = northern_hemisphere['Lat']
y_values = northern_hemisphere['Max Temp']
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
reg_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_values,y_values)
plt.plot(x_values,reg_values,"red")
plt.annotate(line_eq,(5,10),fontsize=15,color="red")
plt.ylim(0,100)
plt.xlim(0, 80)

plt.ylabel("Max. Temp")
plt.xlabel("Latitude")
plt.savefig("North Max Temp vs Latitude Regression.png")

# %% [markdown]
# #Observation: negative correlation between latitude and Max Temperature in Northern Hemisphere

# %% [markdown]
# ####  Southern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
#Create a Scatter Plot for Lattitude vs Temperature of City (Southern Hemisphere)
x_values = southern_hemisphere['Lat']
y_values = southern_hemisphere['Max Temp']
reg_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_values,y_values)
plt.plot(x_values,reg_values,"r-")
plt.annotate(line_eq,(6,10),fontsize=15,color="red")
plt.ylim(30, 100)
plt.xlim(-60, 0, 10)

plt.ylabel("Max. Temp")
plt.xlabel("Latitude")
plt.savefig("South Max Temp vs Latitude Regression.png")

# %% [markdown]
# #Observation: Positive constant correlation

# %% [markdown]
# ####  Northern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
x_values = northern_hemisphere['Lat']
y_values = northern_hemisphere['Humidity']
reg_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_values,y_values)
plt.plot(x_values,reg_values,"r-")
plt.annotate(line_eq,(6,10),fontsize=15,color="red")
plt.ylabel("Humidity")
plt.xlabel("Latitude")
plt.savefig("North Humidity vs Latitude Linear Regression.png")

# %% [markdown]
# #Observation: Positive constant correlation

# %% [markdown]
# ####  Southern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
x_values = southern_hemisphere['Lat']
y_values = southern_hemisphere['Humidity']
reg_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_values,y_values)
plt.plot(x_values,reg_values,"r-")
plt.annotate(line_eq,(-25,10),fontsize=15,color="red")

plt.ylim(0, 100)

plt.ylabel("Humidity")
plt.xlabel("Latitude")
plt.savefig("South  Humidity vs Latitude Linear Regression.png")

# %% [markdown]
# #Observation: Positive constant correlation

# %% [markdown]
# ####  Northern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
x_values = northern_hemisphere['Lat']
y_values = northern_hemisphere['Cloudiness']
reg_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_values,y_values)
plt.plot(x_values,reg_values,"r-")
plt.annotate(line_eq,(6,10),fontsize=15,color="red")
plt.ylabel("Cloudiness")
plt.xlabel("Latitude")
plt.savefig("North  Cloudiness vs Latitude Linear Regression.png")

# %% [markdown]
# #Observation: low positive positive correlation

# %% [markdown]
# ####  Southern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
x_values = southern_hemisphere['Lat']
y_values = southern_hemisphere['Cloudiness']
reg_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_values,y_values)
plt.plot(x_values,reg_values,"r-")
plt.annotate(line_eq,(-25,10),fontsize=15,color="red")
plt.ylabel("Cloudiness")
plt.xlabel("Latitude")
plt.savefig("South  Cloudiness vs Latitude Linear Regression.png")

# %% [markdown]
# #Observation: Low Positive constant correlation

# %% [markdown]
# ####  Northern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
x_values = northern_hemisphere['Lat']
y_values = northern_hemisphere['Wind Speed']
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
reg_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_values,y_values)
plt.plot(x_values,reg_values,"r-")
plt.annotate(line_eq,(45,22),fontsize=15,color="red")
plt.ylabel("Cloudiness")
plt.xlabel("Latitude")
plt.savefig("North  Wind speed vs Latitude Linear Regression.png")

# %%
#Observation: low positive correlation
